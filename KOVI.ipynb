# %%
-- Criação da tabela para os registros

CREATE TABLE transacoes (
    id INT AUTO_INCREMENT,
    descricao VARCHAR(255),
    valor DECIMAL(10, 2),
    data_emissao DATE,
    status VARCHAR(50),
    PRIMARY KEY (id)
);

-- Inserção dos registros

INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI DO SEU JEITO SEDAN', 1000.00, '2022-01-22', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI DO SEU JEITO SEDAN', 469.00, '2022-01-22', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI DO SEU JEITO SEDAN (30 DIAS DE ESPERA PARA ENTREGA)', 419.00, '2022-03-07', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI DO SEU JEITO SEDAN (30 DIAS DE ESPERA PARA ENTREGA)', 469.00, '2022-03-14', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI DO SEU JEITO SEDAN (30 DIAS DE ESPERA PARA ENTREGA)', 419.00, '2022-03-21', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI DO SEU JEITO SEDAN (30 DIAS DE ESPERA PARA ENTREGA)', 419.00, '2022-03-28', 'Saldo Creditado');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('CAUÇÃO. PLANO KOVI DO SEU JEITO SEDAN (30 DIAS DE ESPERA PARA ENTREGA)', 1000.00, '2022-04-05', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI DO SEU JEITO SEDAN (30 DIAS DE ESPERA PARA ENTREGA)', 469.00, '2022-04-08', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI DO SEU JEITO SEDAN (30 DIAS DE ESPERA PARA ENTREGA)', 419.00, '2022-04-11', 'Pago');

--

-- Inserção dos registros adicionais

INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI DO SEU JEITO SEDAN (30 DIAS DE ESPERA PARA ENTREGA)', 419.00, '2022-04-18', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI DO SEU JEITO SEDAN (30 DIAS DE ESPERA PARA ENTREGA)', 419.00, '2022-04-25', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('COPARTICIPAÇÃO POR COLISÃO - KOVI / PARCELA 1', 575.00, '2022-04-26', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI DO SEU JEITO SEDAN (30 DIAS DE ESPERA PARA ENTREGA)', 469.00, '2022-05-02', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI DO SEU JEITO SEDAN (30 DIAS DE ESPERA PARA ENTREGA)', 419.00, '2022-05-09', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI DO SEU JEITO SEDAN (30 DIAS DE ESPERA PARA ENTREGA)', 419.00, '2022-05-16', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI DO SEU JEITO SEDAN (30 DIAS DE ESPERA PARA ENTREGA)', 419.00, '2022-05-23', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI DO SEU JEITO SEDAN (30 DIAS DE ESPERA PARA ENTREGA)', 419.00, '2022-05-30', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI DO SEU JEITO SEDAN (30 DIAS DE ESPERA PARA ENTREGA)', 419.00, '2022-06-06', 'Pago');

-- Inserção dos registros adicionais

INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI DO SEU JEITO SEDAN (30 DIAS DE ESPERA PARA ENTREGA)', 419.00, '2022-06-13', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('COPARTICIPAÇÃO POR COLISÃO - KOVI / PARCELA 2', 575.00, '2022-06-13', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI DO SEU JEITO SEDAN (35 DIAS DE ESPERA PARA ENTREGA)', 419.00, '2022-06-20', 'Saldo Creditado');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('CAUÇÃO. PLANO KOVI DO SEU JEITO SEDAN (35 DIAS DE ESPERA PARA ENTREGA)', 1000.00, '2022-06-21', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI DO SEU JEITO SEDAN (35 DIAS DE ESPERA PARA ENTREGA)', 419.00, '2022-06-27', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI DO SEU JEITO SEDAN (35 DIAS DE ESPERA PARA ENTREGA)', 419.00, '2022-07-04', 'Saldo Creditado');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI DO SEU JEITO SEDAN (35 DIAS DE ESPERA PARA ENTREGA)', 419.00, '2022-07-11', 'Saldo Creditado');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('OUTROS', 440.00, '2022-07-15', 'Pago');

-- Inserção dos registros adicionais

INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('LOJA KOVI - DEPÓSITO KOVI PRÓPRIO 1/5', 1400.00, '2022-07-19', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02', 459.00, '2022-07-20', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('COPARTICIPAÇÃO POR COLISÃO - KOVI / PARCELA 3', 575.00, '2022-07-24', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02', 459.00, '2022-07-26', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02', 459.00, '2022-08-02', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02', 459.00, '2022-08-09', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 459.00, '2022-08-16', 'Saldo Creditado');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('LOJA KOVI - DEPÓSITO KOVI PRÓPRIO 2/5', 1400.00, '2022-08-22', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 459.00, '2022-08-23', 'Pago');

-- Inserção dos registros adicionais

INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 459.00, '2022-08-30', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 459.00, '2022-09-06', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 459.00, '2022-09-13', 'Saldo Creditado');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('LOJA KOVI - DEPÓSITO KOVI PRÓPRIO 3/5', 1400.00, '2022-09-20', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 459.00, '2022-09-20', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 459.00, '2022-09-27', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 505.05, '2022-10-04', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 459.00, '2022-10-11', 'Pago');

-- Inserção dos registros adicionais

INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('LOJA KOVI - DEPÓSITO KOVI PRÓPRIO 4/5', 1400.00, '2022-10-20', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 459.00, '2022-10-25', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 459.00, '2022-11-01', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 459.00, '2022-11-08', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 459.00, '2022-11-15', 'Saldo Creditado');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('LOJA KOVI - DEPÓSITO KOVI PRÓPRIO 5/5', 1400.00, '2022-11-21', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 459.00, '2022-11-22', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 459.00, '2022-11-29', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 459.00, '2022-12-06', 'Pago');

-- Inserção dos registros adicionais

INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 459.00, '2022-12-13', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 459.00, '2022-12-20', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 459.00, '2022-12-27', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('NEGOCIACAO DE PAGAMENTO 04-01-2023', 505.05, '2023-01-03', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('NEGOCIACAO DE PAGAMENTO 04-01-2023 1/1', 505.05, '2023-01-04', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 459.00, '2023-01-10', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 459.00, '2023-01-17', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 459.00, '2023-01-24', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('INFRAÇÃO DE TRÂNSITO M540040064: TRANSITAR COM O VEICULO EM MARCAS DE CANALIZACAO - AV VER ANGELINA PRETTI DA SILVA, SAO VICENTE, BR', 1056.49, '2023-01-30', 'Pago');

-- Inserção dos registros adicionais

INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 459.00, '2023-01-31', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 459.00, '2023-02-07', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 459.00, '2023-02-14', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 459.00, '2023-02-21', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('NEGOCIACAO DE PAGAMENTO 01-03-2023', 505.05, '2023-02-28', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('NEGOCIACAO DE PAGAMENTO 01-03-2023 1/1', 505.05, '2023-03-01', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 459.00, '2023-03-07', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 459.00, '2023-03-14', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 505.05, '2023-03-21', 'Pago');

-- Inserção dos registros adicionais

INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 505.35, '2023-03-28', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 459.00, '2023-04-04', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PROPRIO 48 + 12 - CARRO SEMINOVO - GRUPO 02 (ATÉ 15/AGO/2022)', 459.00, '2023-04-11', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('CAUÇÃO. PLANO KOVI PRÓPRIO - 48+18 - GRUPO 09 - CAUÇÃO R$7.000', 7000.00, '2023-04-20', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PRÓPRIO - 48+18 - GRUPO 09 - CAUÇÃO R$7.000', 629.00, '2023-04-20', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PRÓPRIO - 48+18 - GRUPO 09 - CAUÇÃO R$7.000', 692.11, '2023-04-26', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('INFRAÇÃO DE TRÂNSITO GRA7565373: TRANSITAR EM LOCALHORARIO NAO PERMITIDO PELA REGULAMENTACAO RODIZIO - LOCAL MARGINAL TIETE, PTA CENTRAL (A. SENNA/C.BRANCO) A MENOS 28M PONTE DAS BANDEIRAS, SAO PAULO, BR', 172.38, '2023-04-27', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PRÓPRIO - 48+18 - GRUPO 09 - CAUÇÃO R$7.000', 629.00, '2023-05-03', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('MANUTENÇÃO/AVARIAS NO CARRO 1/2', 415.75, '2023-05-05', 'Pago');

-- Inserção dos registros adicionais

INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PRÓPRIO - 48+18 - GRUPO 09 - CAUÇÃO R$7.000', 629.00, '2023-05-10', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PRÓPRIO - 48+18 - GRUPO 09 - CAUÇÃO R$7.000', 692.32, '2023-05-17', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PRÓPRIO - 48+18 - GRUPO 09 - CAUÇÃO R$7.000', 692.53, '2023-05-24', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('MANUTENÇÃO/AVARIAS NO CARRO', 416.01, '2023-05-26', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PRÓPRIO - 48+18 - GRUPO 09 - CAUÇÃO R$7.000', 629.00, '2023-05-31', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PRÓPRIO - 48+18 - GRUPO 09 - CAUÇÃO R$7.000', 692.32, '2023-06-07', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PRÓPRIO - 48+18 - GRUPO 09 - CAUÇÃO R$7.000', 629.00, '2023-06-14', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PRÓPRIO - 48+18 - GRUPO 09 - CAUÇÃO R$7.000', 692.53, '2023-06-21', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PRÓPRIO - 48+18 - GRUPO 09 - CAUÇÃO R$7.000', 629.00, '2023-06-28', 'Pago');

-- Inserção dos registros adicionais

INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('INFRAÇÃO DE TRÂNSITO PMC1663595: ESTACIONAR EM LOCALHORARIO PROIBIDO ESPECIFICAMENTE PELA SINALIZACAO - ESTRADA DA COLONIA MARIO REIMBERG CHRISTE , DEFR, SAO PAULO, BR', 124.96, '2023-07-03', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PRÓPRIO - 48+18 - GRUPO 09 - CAUÇÃO R$7.000', 692.53, '2023-07-05', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PRÓPRIO - 48+18 - GRUPO 09 - CAUÇÃO R$7.000', 629.00, '2023-07-12', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('COBRANÇA NO-SHOW', 200.00, '2023-07-12', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PRÓPRIO - 48+18 - GRUPO 09 - CAUÇÃO R$7.000', 629.00, '2023-07-19', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PRÓPRIO - 48+18 - GRUPO 09 - CAUÇÃO R$7.000', 629.00, '2023-07-26', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PRÓPRIO - 48+18 - GRUPO 09 - CAUÇÃO R$7.000', 629.00, '2023-08-02', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PRÓPRIO - 48+18 - GRUPO 09 - CAUÇÃO R$7.000', 629.00, '2023-08-09', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PRÓPRIO - 48+18 - GRUPO 09 - CAUÇÃO R$7.000', 629.00, '2023-08-16', 'Pago');

-- Inserção dos registros mais recentes

INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PRÓPRIO - 48+18 - GRUPO 09 - CAUÇÃO R$7.000', 629.00, '2023-08-23', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PRÓPRIO - 48+18 - GRUPO 09 - CAUÇÃO R$7.000', 692.32, '2023-08-30', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PRÓPRIO - 48+18 - GRUPO 09 - CAUÇÃO R$7.000', 629.00, '2023-09-06', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PRÓPRIO - 48+18 - GRUPO 09 - CAUÇÃO R$7.000', 629.00, '2023-09-13', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PRÓPRIO - 48+18 - GRUPO 09 - CAUÇÃO R$7.000', 629.00, '2023-09-20', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PRÓPRIO - 48+18 - GRUPO 09 - CAUÇÃO R$7.000', 629.00, '2023-09-27', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PRÓPRIO - 48+18 - GRUPO 09 - CAUÇÃO R$7.000', 629.00, '2023-10-04', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PRÓPRIO - 48+18 - GRUPO 09 - CAUÇÃO R$7.000', 629.00, '2023-10-11', 'Pago');
INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI PRÓPRIO - 48+18 - GRUPO 09 - CAUÇÃO R$7.000', 692.78, '2023-10-18', 'Pago');
# Out:
#   File "/tmp/ipykernel_11769/3891006041.py", line 1
#     -- Criação da tabela para os registros
#                ^
# SyntaxError: invalid syntax

# %%
import java.sql.Connection;
import java.sql.DriverManager;
import java.sql.SQLException;
import java.sql.Statement;

public class H2Database {
    public static void main(String[] args) {
        try {
            // Carregar o driver do banco de dados H2
            Class.forName("org.h2.Driver");

            // Estabelecer a conexão com o banco de dados
            Connection connection = DriverManager.getConnection("jdbc:h2:~/test", "sa", "");

            // Criar a tabela "transacoes"
            Statement statement = connection.createStatement();
            String createTableSQL = "CREATE TABLE transacoes (" +
                    "id INT AUTO_INCREMENT, " +
                    "descricao VARCHAR(255), " +
                    "valor DECIMAL(10, 2), " +
                    "data_emissao DATE, " +
                    "status VARCHAR(50), " +
                    "PRIMARY KEY (id)" +
                    ")";
            statement.executeUpdate(createTableSQL);

            // Inserir os registros
            String[] insertQueries = {
                    "INSERT INTO transacoes (descricao, valor, data_emissao, status) VALUES ('PLANO KOVI DO SEU JEITO SEDAN', 1000.00, '2022-01-22', 'Pago')",
                    // Insira os demais registros aqui...
            };

            for (String insertQuery : insertQueries) {
                statement.executeUpdate(insertQuery);
            }

            // Fechar a conexão
            statement.close();
            connection.close();
        } catch (ClassNotFoundException | SQLException e) {
            e.printStackTrace();
        }
    }
}
