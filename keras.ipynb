# %%
import tensorflow_decision_forests as tfdf
import pandas as pd

dataset = pd.read_csv("project/dataset.csv")
tf_dataset = tfdf.keras.pd_dataframe_to_tf_dataset(dataset, label="my_label")

model = tfdf.keras.RandomForestModel()
model.fit(tf_dataset)

print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import tensorflow_decision_forests as tfdf
#       2 import pandas as pd
#       4 dataset = pd.read_csv("project/dataset.csv")
#
# ModuleNotFoundError: No module named 'tensorflow_decision_forests'

# %%
conda install tensorflow
# Out:
# /media/obarreto/MSDOSX/library-iso/anaconda-navigator/lib/python3.11/site-packages/conda/base/context.py:201: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# /media/obarreto/MSDOSX/library-iso/anaconda-navigator/lib/python3.11/site-packages/conda/base/context.py:201: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# Channels:
#  - defaults
# Platform: linux-64
# doneng package metadata (repodata.json): -
# | warning  libmamba Added empty dependency for problem type SOLVER_RULE_UPDATE
# done
#
# ## Package Plan ##
#
#   environment location: /media/obarreto/MSDOSX/library-iso/anaconda-navigator
#
#   added / updated specs:
#     - tensorflow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     arrow-cpp-19.0.0           |       h865e1df_1        12.5 MB
#     aws-sdk-cpp-1.11.212       |       hecad206_0         3.8 MB
#     gast-0.5.3                 |     pyhd3eb1b0_0          21 KB
#     grpcio-1.62.2              |  py311h6a678d5_0         1.1 MB
#     h5py-3.12.1                |  py311h5842655_1         1.4 MB
#     hdf5-1.14.5                |       h2b7332f_2         5.9 MB
#     keras-3.6.0                |  py311h06a4308_0         3.0 MB
#     libabseil-20240116.2       | cxx17_h6a678d5_0         1.3 MB
#     libgrpc-1.62.2             |       h2d74bed_0         8.0 MB
#     libprotobuf-4.25.3         |       he621ea3_0         2.8 MB
#     ml_dtypes-0.4.0            |  py311ha02d727_0         171 KB
#     namex-0.0.7                |  py311h06a4308_0          16 KB
#     optree-0.14.1              |  py311hdb19cb5_0         420 KB
#     orc-2.0.1                  |       h2d29ad5_0         1.1 MB
#     protobuf-4.25.3            |  py311he36ed58_1         409 KB
#     pyarrow-19.0.0             |  py311h6a678d5_1         7.3 MB
#     pytables-3.10.2            |  py311h759fa19_1         1.7 MB
#     snappy-1.2.1               |       h6a678d5_0          46 KB
#     tensorboard-2.17.0         |  py311h06a4308_0         5.7 MB
#     tensorflow-2.17.0          |cpu_py311hbca4264_0          33 KB
#     tensorflow-base-2.17.0     |cpu_py311hb07566e_0       156.0 MB
#     tensorflow-estimator-2.17.0|cpu_py311hfedf350_0         714 KB
#     ------------------------------------------------------------
#                                            Total:       213.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   absl-py            pkgs/main/linux-64::absl-py-2.1.0-py311h06a4308_0
#   astunparse         pkgs/main/noarch::astunparse-1.6.3-py_0
#   flatbuffers        pkgs/main/linux-64::flatbuffers-24.3.25-h6a678d5_0
#   gast               pkgs/main/noarch::gast-0.5.3-pyhd3eb1b0_0
#   google-pasta       pkgs/main/noarch::google-pasta-0.2.0-pyhd3eb1b0_0
#   grpcio             pkgs/main/linux-64::grpcio-1.62.2-py311h6a678d5_0
#   keras              pkgs/main/linux-64::keras-3.6.0-py311h06a4308_0
#   libabseil          pkgs/main/linux-64::libabseil-20240116.2-cxx17_h6a678d5_0
#   libgrpc            pkgs/main/linux-64::libgrpc-1.62.2-h2d74bed_0
#   ml_dtypes          pkgs/main/linux-64::ml_dtypes-0.4.0-py311ha02d727_0
#   namex              pkgs/main/linux-64::namex-0.0.7-py311h06a4308_0
#   opt_einsum         pkgs/main/noarch::opt_einsum-3.3.0-pyhd3eb1b0_1
#   optree             pkgs/main/linux-64::optree-0.14.1-py311hdb19cb5_0
#   python-flatbuffers pkgs/main/linux-64::python-flatbuffers-24.3.25-py311h06a4308_0
#   tensorboard        pkgs/main/linux-64::tensorboard-2.17.0-py311h06a4308_0
#   tensorboard-data-~ pkgs/main/linux-64::tensorboard-data-server-0.7.0-py311h52d8a92_1
#   tensorflow         pkgs/main/linux-64::tensorflow-2.17.0-cpu_py311hbca4264_0
#   tensorflow-base    pkgs/main/linux-64::tensorflow-base-2.17.0-cpu_py311hb07566e_0
#   tensorflow-estima~ pkgs/main/linux-64::tensorflow-estimator-2.17.0-cpu_py311hfedf350_0
#   termcolor          pkgs/main/linux-64::termcolor-2.1.0-py311h06a4308_0
#
# The following packages will be REMOVED:
#
#   abseil-cpp-20211102.0-hd4dd3e8_0
#   grpc-cpp-1.48.2-he1ff14a_1
#
# The following packages will be UPDATED:
#
#   arrow-cpp                               14.0.2-h374c478_1 --> 19.0.0-h865e1df_1
#   aws-sdk-cpp                            1.10.55-h721c034_0 --> 1.11.212-hecad206_0
#   h5py                                3.9.0-py311hdd6beaf_0 --> 3.12.1-py311h5842655_1
#   hdf5                                    1.12.1-h2b7332f_3 --> 1.14.5-h2b7332f_2
#   libprotobuf                             3.20.3-he621ea3_0 --> 4.25.3-he621ea3_0
#   orc                                      1.7.4-hb3bc3d3_1 --> 2.0.1-h2d29ad5_0
#   protobuf                           3.20.3-py311h6a678d5_0 --> 4.25.3-py311he36ed58_1
#   pyarrow                            14.0.2-py311hb6e97c4_0 --> 19.0.0-py311h6a678d5_1
#   pytables                            3.9.2-py311h9d13977_0 --> 3.10.2-py311h759fa19_1
#   snappy                                  1.1.10-h6a678d5_1 --> 1.2.1-h6a678d5_0
#   sqlite                                  3.41.2-h5eee18b_0 --> 3.45.3-h5eee18b_0
#
#
#
# Downloading and Extracting Packages:
# tensorflow-base-2.17 | 156.0 MB  |                                       |   0%
# arrow-cpp-19.0.0     | 12.5 MB   |                                       |   0%
#
# libgrpc-1.62.2       | 8.0 MB    |                                       |   0%
#
#
# pyarrow-19.0.0       | 7.3 MB    |                                       |   0%
#
#
#
# hdf5-1.14.5          | 5.9 MB    |                                       |   0%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    |                                       |   0%
#
#
#
#
#
# aws-sdk-cpp-1.11.212 | 3.8 MB    |                                       |   0%
#
#
#
#
#
#
# keras-3.6.0          | 3.0 MB    |                                       |   0%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    |                                       |   0%
#
#
#
#
#
#
#
#
# pytables-3.10.2      | 1.7 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# h5py-3.12.1          | 1.4 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# libabseil-20240116.2 | 1.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# orc-2.0.1            | 1.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# grpcio-1.62.2        | 1.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-estimator | 714 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# optree-0.14.1        | 420 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# protobuf-4.25.3      | 409 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ml_dtypes-0.4.0      | 171 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# snappy-1.2.1         | 46 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-2.17.0    | 33 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gast-0.5.3           | 21 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  |                                       |   0%
# tensorflow-base-2.17 | 156.0 MB  |                                       |   0%
# tensorflow-base-2.17 | 156.0 MB  |                                       |   0%
#
#
# pyarrow-19.0.0       | 7.3 MB    |                                       |   0%
#
# tensorflow-base-2.17 | 156.0 MB  |                                       |   0%
# arrow-cpp-19.0.0     | 12.5 MB   | 4                                     |   1%
#
#
# pyarrow-19.0.0       | 7.3 MB    | 3                                     |   1%
#
#
#
# tensorflow-base-2.17 | 156.0 MB  |                                       |   0%
# tensorflow-base-2.17 | 156.0 MB  |                                       |   0%
#
# libgrpc-1.62.2       | 8.0 MB    | 2                                     |   1%
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | 1                                     |   0%
# arrow-cpp-19.0.0     | 12.5 MB   | 8                                     |   2%
#
#
# pyarrow-19.0.0       | 7.3 MB    | 4                                     |   1%
#
#
# tensorflow-base-2.17 | 156.0 MB  | 1                                     |   0%
#
# libgrpc-1.62.2       | 8.0 MB    | 4                                     |   1%
#
#
# pyarrow-19.0.0       | 7.3 MB    | #6                                    |   4%
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | 1                                     |   1%
#
# libgrpc-1.62.2       | 8.0 MB    | 5                                     |   1%
#
#
#
# hdf5-1.14.5          | 5.9 MB    | 9                                     |   3%
# arrow-cpp-19.0.0     | 12.5 MB   | 9                                     |   3%
#
# tensorflow-base-2.17 | 156.0 MB  | 2                                     |   1%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ##                                    |   6%
#
#
#
# hdf5-1.14.5          | 5.9 MB    | #4                                    |   4%
# tensorflow-base-2.17 | 156.0 MB  | 2                                     |   1%
#
# libgrpc-1.62.2       | 8.0 MB    | 9                                     |   3%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ##6                                   |   7%
#
#
#
# hdf5-1.14.5          | 5.9 MB    | ##9                                   |   8%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ##9                                   |   8%
#
#
#
# hdf5-1.14.5          | 5.9 MB    | ####3                                 |  12%
#
# libgrpc-1.62.2       | 8.0 MB    | #                                     |   3%
# tensorflow-base-2.17 | 156.0 MB  | 2                                     |   1%
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | 3                                     |   1%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ###4                                  |   9%
# arrow-cpp-19.0.0     | 12.5 MB   | ###                                   |   8%
#
# libgrpc-1.62.2       | 8.0 MB    | #2                                    |   3%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ####                                  |  11%
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | 3                                     |   1%
#
# libgrpc-1.62.2       | 8.0 MB    | #5                                    |   4%
#
#
# tensorflow-base-2.17 | 156.0 MB  | 3                                     |   1%
# arrow-cpp-19.0.0     | 12.5 MB   | ###2                                  |   9%
#
# libgrpc-1.62.2       | 8.0 MB    | #7                                    |   5%
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | 3                                     |   1%
# arrow-cpp-19.0.0     | 12.5 MB   | ###5                                  |  10%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ####7                                 |  13%
#
#
#
# hdf5-1.14.5          | 5.9 MB    | #########7                            |  26%
#
# tensorflow-base-2.17 | 156.0 MB  | 4                                     |   1%
#
#
# pyarrow-19.0.0       | 7.3 MB    | #####                                 |  14%
# arrow-cpp-19.0.0     | 12.5 MB   | ###7                                  |  10%
#
#
#
# hdf5-1.14.5          | 5.9 MB    | ##########6                           |  29%
#
# tensorflow-base-2.17 | 156.0 MB  | 4                                     |   1%
# arrow-cpp-19.0.0     | 12.5 MB   | ###9                                  |  11%
#
#
# pyarrow-19.0.0       | 7.3 MB    | #####3                                |  14%
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | 4                                     |   1%
#
# libgrpc-1.62.2       | 8.0 MB    | ##2                                   |   6%
#
#
# pyarrow-19.0.0       | 7.3 MB    | #####6                                |  15%
#
#
#
# hdf5-1.14.5          | 5.9 MB    | ############8                         |  35%
# arrow-cpp-19.0.0     | 12.5 MB   | ####1                                 |  11%
#
# tensorflow-base-2.17 | 156.0 MB  | 4                                     |   1%
#
#
#
# hdf5-1.14.5          | 5.9 MB    | #############7                        |  37%
# arrow-cpp-19.0.0     | 12.5 MB   | ####3                                 |  12%
#
#
# tensorflow-base-2.17 | 156.0 MB  | 5                                     |   1%
#
# libgrpc-1.62.2       | 8.0 MB    | ##5                                   |   7%
#
#
#
# hdf5-1.14.5          | 5.9 MB    | ##############6                       |  39%
# arrow-cpp-19.0.0     | 12.5 MB   | ####4                                 |  12%
#
#
# tensorflow-base-2.17 | 156.0 MB  | 5                                     |   1%
#
#
#
# hdf5-1.14.5          | 5.9 MB    | ###############7                      |  43%
# arrow-cpp-19.0.0     | 12.5 MB   | ####7                                 |  13%
#
# libgrpc-1.62.2       | 8.0 MB    | ##7                                   |   7%
#
#
# tensorflow-base-2.17 | 156.0 MB  | 5                                     |   2%
#
#
#
# hdf5-1.14.5          | 5.9 MB    | ################7                     |  45%
#
# libgrpc-1.62.2       | 8.0 MB    | ##8                                   |   8%
# tensorflow-base-2.17 | 156.0 MB  | 6                                     |   2%
#
#
# pyarrow-19.0.0       | 7.3 MB    | #######                               |  19%
#
#
#
# hdf5-1.14.5          | 5.9 MB    | #################7                    |  48%
#
# libgrpc-1.62.2       | 8.0 MB    | ###                                   |   8%
# arrow-cpp-19.0.0     | 12.5 MB   | #####                                 |  14%
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | 6                                     |   2%
#
#
# pyarrow-19.0.0       | 7.3 MB    | #######3                              |  20%
# arrow-cpp-19.0.0     | 12.5 MB   | #####2                                |  14%
#
# libgrpc-1.62.2       | 8.0 MB    | ###1                                  |   9%
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | 6                                     |   2%
#
#
# pyarrow-19.0.0       | 7.3 MB    | #######5                              |  20%
# tensorflow-base-2.17 | 156.0 MB  | 6                                     |   2%
#
# libgrpc-1.62.2       | 8.0 MB    | ###3                                  |   9%
#
#
#
# hdf5-1.14.5          | 5.9 MB    | ####################3                 |  55%
#
#
# pyarrow-19.0.0       | 7.3 MB    | #######8                              |  21%
# tensorflow-base-2.17 | 156.0 MB  | 7                                     |   2%
#
#
#
# hdf5-1.14.5          | 5.9 MB    | #####################4                |  58%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ########2                             |  22%
#
# libgrpc-1.62.2       | 8.0 MB    | ###6                                  |  10%
# tensorflow-base-2.17 | 156.0 MB  | 7                                     |   2%
#
#
#
# hdf5-1.14.5          | 5.9 MB    | ######################3               |  60%
#
# libgrpc-1.62.2       | 8.0 MB    | ###7                                  |  10%
#
#
# tensorflow-base-2.17 | 156.0 MB  | 7                                     |   2%
# arrow-cpp-19.0.0     | 12.5 MB   | ######                                |  16%
#
#
#
# hdf5-1.14.5          | 5.9 MB    | #######################1              |  62%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ########8                             |  24%
#
# tensorflow-base-2.17 | 156.0 MB  | 7                                     |   2%
# arrow-cpp-19.0.0     | 12.5 MB   | ######2                               |  17%
#
#
#
# hdf5-1.14.5          | 5.9 MB    | #######################9              |  65%
#
#
# tensorflow-base-2.17 | 156.0 MB  | 7                                     |   2%
#
# libgrpc-1.62.2       | 8.0 MB    | ####1                                 |  11%
#
#
#
# hdf5-1.14.5          | 5.9 MB    | ########################7             |  67%
# arrow-cpp-19.0.0     | 12.5 MB   | ######3                               |  17%
#
#
# tensorflow-base-2.17 | 156.0 MB  | 8                                     |   2%
#
#
#
# hdf5-1.14.5          | 5.9 MB    | #########################8            |  70%
#
# libgrpc-1.62.2       | 8.0 MB    | ####3                                 |  12%
# arrow-cpp-19.0.0     | 12.5 MB   | ######5                               |  18%
#
#
# tensorflow-base-2.17 | 156.0 MB  | 8                                     |   2%
#
#
#
# hdf5-1.14.5          | 5.9 MB    | ###########################           |  73%
# arrow-cpp-19.0.0     | 12.5 MB   | ######8                               |  18%
#
# tensorflow-base-2.17 | 156.0 MB  | 8                                     |   2%
#
#
# pyarrow-19.0.0       | 7.3 MB    | #########9                            |  27%
#
#
#
# hdf5-1.14.5          | 5.9 MB    | ############################          |  76%
# arrow-cpp-19.0.0     | 12.5 MB   | ######9                               |  19%
#
# tensorflow-base-2.17 | 156.0 MB  | 9                                     |   2%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ##########2                           |  28%
#
#
#
# hdf5-1.14.5          | 5.9 MB    | #############################         |  78%
# arrow-cpp-19.0.0     | 12.5 MB   | #######1                              |  19%
#
# tensorflow-base-2.17 | 156.0 MB  | 9                                     |   3%
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | 9                                     |   3%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ##########5                           |  29%
#
# libgrpc-1.62.2       | 8.0 MB    | ####9                                 |  13%
# arrow-cpp-19.0.0     | 12.5 MB   | #######3                              |  20%
#
#
#
# hdf5-1.14.5          | 5.9 MB    | ###############################8      |  86%
#
# tensorflow-base-2.17 | 156.0 MB  | 9                                     |   3%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ##########9                           |  30%
# arrow-cpp-19.0.0     | 12.5 MB   | #######5                              |  21%
#
#
#
# hdf5-1.14.5          | 5.9 MB    | ################################9     |  89%
#
# libgrpc-1.62.2       | 8.0 MB    | #####3                                |  14%
# tensorflow-base-2.17 | 156.0 MB  | #                                     |   3%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ###########2                          |  30%
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | #                                     |   3%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ###########5                          |  31%
# arrow-cpp-19.0.0     | 12.5 MB   | #######9                              |  22%
#
# libgrpc-1.62.2       | 8.0 MB    | #####5                                |  15%
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | #                                     |   3%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ###########7                          |  32%
# arrow-cpp-19.0.0     | 12.5 MB   | ########1                             |  22%
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | #                                     |   3%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ###########9                          |  32%
# arrow-cpp-19.0.0     | 12.5 MB   | ########3                             |  23%
#
# libgrpc-1.62.2       | 8.0 MB    | #####7                                |  16%
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | #1                                    |   3%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ############6                         |  34%
# arrow-cpp-19.0.0     | 12.5 MB   | ########7                             |  24%
#
# libgrpc-1.62.2       | 8.0 MB    | ######2                               |  17%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | 1                                     |   0%
#
#
# tensorflow-base-2.17 | 156.0 MB  | #1                                    |   3%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | 9                                     |   2%
# arrow-cpp-19.0.0     | 12.5 MB   | ########9                             |  24%
#
# libgrpc-1.62.2       | 8.0 MB    | ######4                               |  17%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | #4                                    |   4%
#
#
# tensorflow-base-2.17 | 156.0 MB  | #1                                    |   3%
# arrow-cpp-19.0.0     | 12.5 MB   | #########1                            |  25%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | ##4                                   |   7%
#
#
# pyarrow-19.0.0       | 7.3 MB    | #############5                        |  37%
#
# tensorflow-base-2.17 | 156.0 MB  | #2                                    |   3%
# arrow-cpp-19.0.0     | 12.5 MB   | #########3                            |  25%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | ###1                                  |   9%
#
#
# pyarrow-19.0.0       | 7.3 MB    | #############8                        |  38%
#
# tensorflow-base-2.17 | 156.0 MB  | #2                                    |   3%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | ###8                                  |  11%
# arrow-cpp-19.0.0     | 12.5 MB   | #########4                            |  26%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ##############1                       |  38%
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | #2                                    |   3%
#
# libgrpc-1.62.2       | 8.0 MB    | #######                               |  19%
# arrow-cpp-19.0.0     | 12.5 MB   | #########6                            |  26%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ##############4                       |  39%
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | #2                                    |   3%
#
# libgrpc-1.62.2       | 8.0 MB    | #######1                              |  19%
# arrow-cpp-19.0.0     | 12.5 MB   | #########7                            |  26%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | ######2                               |  17%
#
#
# tensorflow-base-2.17 | 156.0 MB  | #3                                    |   4%
#
# libgrpc-1.62.2       | 8.0 MB    | #######2                              |  20%
# arrow-cpp-19.0.0     | 12.5 MB   | #########9                            |  27%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | ######9                               |  19%
#
#
# tensorflow-base-2.17 | 156.0 MB  | #3                                    |   4%
# arrow-cpp-19.0.0     | 12.5 MB   | ##########                            |  27%
#
# libgrpc-1.62.2       | 8.0 MB    | #######4                              |  20%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | #######8                              |  21%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ###############3                      |  41%
# arrow-cpp-19.0.0     | 12.5 MB   | ##########2                           |  28%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | ########7                             |  24%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ###############5                      |  42%
#
# libgrpc-1.62.2       | 8.0 MB    | #######6                              |  21%
# arrow-cpp-19.0.0     | 12.5 MB   | ##########4                           |  28%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | #########8                            |  27%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ###############9                      |  43%
#
# libgrpc-1.62.2       | 8.0 MB    | #######8                              |  21%
# arrow-cpp-19.0.0     | 12.5 MB   | ##########6                           |  29%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | ##########8                           |  29%
#
#
# tensorflow-base-2.17 | 156.0 MB  | #3                                    |   4%
#
# libgrpc-1.62.2       | 8.0 MB    | ########                              |  22%
# arrow-cpp-19.0.0     | 12.5 MB   | ##########8                           |  29%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | ###########7                          |  32%
#
#
# tensorflow-base-2.17 | 156.0 MB  | #4                                    |   4%
# arrow-cpp-19.0.0     | 12.5 MB   | ###########                           |  30%
#
# libgrpc-1.62.2       | 8.0 MB    | ########3                             |  22%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | ############6                         |  34%
#
#
# pyarrow-19.0.0       | 7.3 MB    | #################                     |  46%
#
#
#
# hdf5-1.14.5          | 5.9 MB    | ##################################### | 100%
#
#
#
# hdf5-1.14.5          | 5.9 MB    | ##################################### | 100%
# arrow-cpp-19.0.0     | 12.5 MB   | ###########2                          |  30%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | #############8                        |  37%
#
# tensorflow-base-2.17 | 156.0 MB  | #5                                    |   4%
#
#
# pyarrow-19.0.0       | 7.3 MB    | #################4                    |  47%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | ##############8                       |  40%
# arrow-cpp-19.0.0     | 12.5 MB   | ###########4                          |  31%
#
# libgrpc-1.62.2       | 8.0 MB    | ########7                             |  24%
#
#
# tensorflow-base-2.17 | 156.0 MB  | #5                                    |   4%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | ###############8                      |  43%
# arrow-cpp-19.0.0     | 12.5 MB   | ###########7                          |  32%
#
# libgrpc-1.62.2       | 8.0 MB    | ########9                             |  24%
#
#
# tensorflow-base-2.17 | 156.0 MB  | #5                                    |   4%
# arrow-cpp-19.0.0     | 12.5 MB   | ###########9                          |  32%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | ################8                     |  46%
#
# libgrpc-1.62.2       | 8.0 MB    | #########1                            |  25%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ##################6                   |  50%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | #################9                    |  48%
# tensorflow-base-2.17 | 156.0 MB  | #6                                    |   4%
#
# libgrpc-1.62.2       | 8.0 MB    | #########3                            |  25%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ###################                   |  51%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | ##################8                   |  51%
# tensorflow-base-2.17 | 156.0 MB  | #6                                    |   4%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ###################4                  |  52%
#
# libgrpc-1.62.2       | 8.0 MB    | #########6                            |  26%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | ###################8                  |  54%
# tensorflow-base-2.17 | 156.0 MB  | #6                                    |   4%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ###################7                  |  54%
#
# libgrpc-1.62.2       | 8.0 MB    | #########8                            |  27%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | ####################7                 |  56%
# tensorflow-base-2.17 | 156.0 MB  | #6                                    |   5%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ####################1                 |  55%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | #####################6                |  59%
#
# libgrpc-1.62.2       | 8.0 MB    | ##########1                           |  27%
# tensorflow-base-2.17 | 156.0 MB  | #7                                    |   5%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ####################5                 |  56%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | ######################7               |  61%
#
# libgrpc-1.62.2       | 8.0 MB    | ##########3                           |  28%
# tensorflow-base-2.17 | 156.0 MB  | #7                                    |   5%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ####################9                 |  57%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | #######################6              |  64%
#
# libgrpc-1.62.2       | 8.0 MB    | ##########5                           |  28%
# arrow-cpp-19.0.0     | 12.5 MB   | #############6                        |  37%
#
#
# tensorflow-base-2.17 | 156.0 MB  | #7                                    |   5%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | ########################4             |  66%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | #########################2            |  68%
#
#
# pyarrow-19.0.0       | 7.3 MB    | #####################6                |  59%
#
# libgrpc-1.62.2       | 8.0 MB    | ##########7                           |  29%
# tensorflow-base-2.17 | 156.0 MB  | #7                                    |   5%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | #########################9            |  70%
# arrow-cpp-19.0.0     | 12.5 MB   | ##############                        |  38%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ######################1               |  60%
#
# tensorflow-base-2.17 | 156.0 MB  | #8                                    |   5%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | ###########################           |  73%
# arrow-cpp-19.0.0     | 12.5 MB   | ##############2                       |  39%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ######################5               |  61%
#
# tensorflow-base-2.17 | 156.0 MB  | #8                                    |   5%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | ###########################9          |  75%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ######################9               |  62%
# arrow-cpp-19.0.0     | 12.5 MB   | ##############4                       |  39%
#
# tensorflow-base-2.17 | 156.0 MB  | #8                                    |   5%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | ############################8         |  78%
# arrow-cpp-19.0.0     | 12.5 MB   | ##############7                       |  40%
#
# libgrpc-1.62.2       | 8.0 MB    | ###########7                          |  32%
#
#
# pyarrow-19.0.0       | 7.3 MB    | #######################3              |  63%
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | #8                                    |   5%
# arrow-cpp-19.0.0     | 12.5 MB   | ##############9                       |  40%
#
#
# pyarrow-19.0.0       | 7.3 MB    | #######################6              |  64%
#
# libgrpc-1.62.2       | 8.0 MB    | ###########9                          |  32%
# tensorflow-base-2.17 | 156.0 MB  | #9                                    |   5%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | ##############################5       |  83%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ########################1             |  65%
#
# libgrpc-1.62.2       | 8.0 MB    | ############2                         |  33%
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | #9                                    |   5%
# arrow-cpp-19.0.0     | 12.5 MB   | ###############4                      |  42%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ########################5             |  66%
#
# libgrpc-1.62.2       | 8.0 MB    | ############4                         |  34%
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | #9                                    |   5%
# arrow-cpp-19.0.0     | 12.5 MB   | ###############6                      |  42%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ########################8             |  67%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | ################################7     |  88%
#
# tensorflow-base-2.17 | 156.0 MB  | #9                                    |   5%
# arrow-cpp-19.0.0     | 12.5 MB   | ###############8                      |  43%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | #################################4    |  90%
#
#
# pyarrow-19.0.0       | 7.3 MB    | #########################1            |  68%
#
# libgrpc-1.62.2       | 8.0 MB    | ############9                         |  35%
# arrow-cpp-19.0.0     | 12.5 MB   | ################                      |  43%
#
#
# pyarrow-19.0.0       | 7.3 MB    | #########################4            |  69%
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | #9                                    |   5%
#
#
# tensorflow-base-2.17 | 156.0 MB  | ##                                    |   5%
#
#
# tensorflow-base-2.17 | 156.0 MB  | ##1                                   |   6%
#
# libgrpc-1.62.2       | 8.0 MB    | #############1                        |  36%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ##########################5           |  72%
# arrow-cpp-19.0.0     | 12.5 MB   | ################2                     |  44%
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ##1                                   |   6%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | ##################################### | 100%
#
# libgrpc-1.62.2       | 8.0 MB    | ##############8                       |  40%
# arrow-cpp-19.0.0     | 12.5 MB   | ##################                    |  49%
#
#
# tensorflow-base-2.17 | 156.0 MB  | ##1                                   |   6%
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ##1                                   |   6%
#
# libgrpc-1.62.2       | 8.0 MB    | ###############3                      |  41%
#
#
#
#
#
# aws-sdk-cpp-1.11.212 | 3.8 MB    | #6                                    |   5%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | ##################################### | 100%
#
#
#
#
# tensorboard-2.17.0   | 5.7 MB    | ##################################### | 100%
#
#
# tensorflow-base-2.17 | 156.0 MB  | ##2                                   |   6%
#
#
#
#
#
# aws-sdk-cpp-1.11.212 | 3.8 MB    | ###                                   |   8%
#
# libgrpc-1.62.2       | 8.0 MB    | ###############7                      |  43%
# tensorflow-base-2.17 | 156.0 MB  | ##2                                   |   6%
#
#
# pyarrow-19.0.0       | 7.3 MB    | #############################6        |  80%
#
#
#
#
#
# aws-sdk-cpp-1.11.212 | 3.8 MB    | ####4                                 |  12%
#
# tensorflow-base-2.17 | 156.0 MB  | ##2                                   |   6%
#
#
#
#
#
# aws-sdk-cpp-1.11.212 | 3.8 MB    | ######                                |  16%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ##############################1       |  81%
# tensorflow-base-2.17 | 156.0 MB  | ##2                                   |   6%
#
# libgrpc-1.62.2       | 8.0 MB    | ################4                     |  44%
#
#
#
#
#
# aws-sdk-cpp-1.11.212 | 3.8 MB    | #######5                              |  20%
# tensorflow-base-2.17 | 156.0 MB  | ##2                                   |   6%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ##############################5       |  83%
#
#
#
#
#
# aws-sdk-cpp-1.11.212 | 3.8 MB    | #########                             |  25%
# tensorflow-base-2.17 | 156.0 MB  | ##3                                   |   6%
#
#
#
#
#
# aws-sdk-cpp-1.11.212 | 3.8 MB    | ##########6                           |  29%
#
# libgrpc-1.62.2       | 8.0 MB    | ################8                     |  45%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ##############################9       |  84%
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ##3                                   |   6%
# arrow-cpp-19.0.0     | 12.5 MB   | ####################2                 |  55%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ###############################2      |  84%
#
# libgrpc-1.62.2       | 8.0 MB    | #################4                    |  47%
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ##3                                   |   6%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ###############################5      |  85%
# tensorflow-base-2.17 | 156.0 MB  | ##3                                   |   6%
#
# libgrpc-1.62.2       | 8.0 MB    | #################7                    |  48%
#
#
# tensorflow-base-2.17 | 156.0 MB  | ##4                                   |   7%
# arrow-cpp-19.0.0     | 12.5 MB   | #####################1                |  57%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ################################1     |  87%
#
# libgrpc-1.62.2       | 8.0 MB    | ##################                    |  49%
#
#
#
#
#
# aws-sdk-cpp-1.11.212 | 3.8 MB    | ################6                     |  45%
# arrow-cpp-19.0.0     | 12.5 MB   | #####################5                |  58%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ################################4     |  88%
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ##4                                   |   7%
#
# libgrpc-1.62.2       | 8.0 MB    | ##################4                   |  50%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ################################6     |  88%
# arrow-cpp-19.0.0     | 12.5 MB   | #####################9                |  59%
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ##4                                   |   7%
#
# libgrpc-1.62.2       | 8.0 MB    | ###################2                  |  52%
# arrow-cpp-19.0.0     | 12.5 MB   | ######################3               |  60%
#
#
# pyarrow-19.0.0       | 7.3 MB    | #################################1    |  90%
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ##5                                   |   7%
#
#
#
#
#
# aws-sdk-cpp-1.11.212 | 3.8 MB    | ##########################6           |  72%
#
#
# pyarrow-19.0.0       | 7.3 MB    | #################################3    |  90%
# arrow-cpp-19.0.0     | 12.5 MB   | ######################6               |  61%
#
# libgrpc-1.62.2       | 8.0 MB    | ###################5                  |  53%
#
#
# pyarrow-19.0.0       | 7.3 MB    | #################################6    |  91%
# tensorflow-base-2.17 | 156.0 MB  | ##5                                   |   7%
#
# libgrpc-1.62.2       | 8.0 MB    | ###################8                  |  54%
#
#
#
#
#
# aws-sdk-cpp-1.11.212 | 3.8 MB    | ############################5         |  77%
#
#
# pyarrow-19.0.0       | 7.3 MB    | #################################8    |  91%
# arrow-cpp-19.0.0     | 12.5 MB   | #######################2              |  63%
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ##5                                   |   7%
#
# libgrpc-1.62.2       | 8.0 MB    | ####################1                 |  54%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ##################################    |  92%
#
#
#
#
#
# aws-sdk-cpp-1.11.212 | 3.8 MB    | ###############################8      |  86%
# tensorflow-base-2.17 | 156.0 MB  | ##5                                   |   7%
#
# libgrpc-1.62.2       | 8.0 MB    | ####################4                 |  55%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ##################################4   |  93%
# arrow-cpp-19.0.0     | 12.5 MB   | #######################9              |  65%
#
#
#
#
#
# aws-sdk-cpp-1.11.212 | 3.8 MB    | #################################4    |  90%
#
# tensorflow-base-2.17 | 156.0 MB  | ##5                                   |   7%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ##################################7   |  94%
#
#
#
#
#
# aws-sdk-cpp-1.11.212 | 3.8 MB    | ##################################9   |  95%
# arrow-cpp-19.0.0     | 12.5 MB   | ########################2             |  66%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ###################################1  |  95%
#
#
#
#
#
# aws-sdk-cpp-1.11.212 | 3.8 MB    | ####################################5 |  99%
#
# tensorflow-base-2.17 | 156.0 MB  | ##5                                   |   7%
# arrow-cpp-19.0.0     | 12.5 MB   | ########################5             |  66%
#
#
#
#
#
# aws-sdk-cpp-1.11.212 | 3.8 MB    | ##################################### | 100%
#
#
# tensorflow-base-2.17 | 156.0 MB  | ##5                                   |   7%
#
# libgrpc-1.62.2       | 8.0 MB    | #####################3                |  58%
# arrow-cpp-19.0.0     | 12.5 MB   | ########################8             |  67%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ###################################6  |  96%
#
#
#
#
#
#
# keras-3.6.0          | 3.0 MB    | 1                                     |   1%
#
# tensorflow-base-2.17 | 156.0 MB  | ##6                                   |   7%
# tensorflow-base-2.17 | 156.0 MB  | ##6                                   |   7%
#
# libgrpc-1.62.2       | 8.0 MB    | ######################4               |  61%
# arrow-cpp-19.0.0     | 12.5 MB   | ##########################2           |  71%
#
#
#
#
#
#
# keras-3.6.0          | 3.0 MB    | #########4                            |  25%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ##################################### | 100%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ##################################### | 100%
# tensorflow-base-2.17 | 156.0 MB  | ##6                                   |   7%
#
# libgrpc-1.62.2       | 8.0 MB    | ######################8               |  62%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | 2                                     |   1%
#
# tensorflow-base-2.17 | 156.0 MB  | ##6                                   |   7%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | #                                     |   3%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | #8                                    |   5%
#
# libgrpc-1.62.2       | 8.0 MB    | #######################6              |  64%
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ##7                                   |   7%
# arrow-cpp-19.0.0     | 12.5 MB   | ###########################1          |  73%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | ##6                                   |   7%
# arrow-cpp-19.0.0     | 12.5 MB   | ###########################4          |  74%
#
# tensorflow-base-2.17 | 156.0 MB  | ##7                                   |   7%
#
#
#
#
#
#
# keras-3.6.0          | 3.0 MB    | #####################1                |  57%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | ###4                                  |   9%
# arrow-cpp-19.0.0     | 12.5 MB   | ###########################7          |  75%
#
# tensorflow-base-2.17 | 156.0 MB  | ##7                                   |   7%
#
#
#
#
#
#
# keras-3.6.0          | 3.0 MB    | ########################4             |  66%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | ####2                                 |  12%
#
#
# pyarrow-19.0.0       | 7.3 MB    | ##################################### | 100%
#
#
#
#
#
# aws-sdk-cpp-1.11.212 | 3.8 MB    | ##################################### | 100%
#
# libgrpc-1.62.2       | 8.0 MB    | ########################4             |  66%
# tensorflow-base-2.17 | 156.0 MB  | ##7                                   |   7%
# arrow-cpp-19.0.0     | 12.5 MB   | ############################3         |  77%
#
#
#
#
#
#
# keras-3.6.0          | 3.0 MB    | ##########################9           |  73%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | ####8                                 |  13%
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ##7                                   |   7%
# arrow-cpp-19.0.0     | 12.5 MB   | ############################5         |  77%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | #####9                                |  16%
#
# libgrpc-1.62.2       | 8.0 MB    | ########################6             |  67%
#
#
#
#
#
#
# keras-3.6.0          | 3.0 MB    | ################################7     |  88%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | ######7                               |  18%
# arrow-cpp-19.0.0     | 12.5 MB   | #############################         |  78%
#
# libgrpc-1.62.2       | 8.0 MB    | #########################2            |  68%
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ##7                                   |   7%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | #######3                              |  20%
# tensorflow-base-2.17 | 156.0 MB  | ##7                                   |   8%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | #########1                            |  25%
# tensorflow-base-2.17 | 156.0 MB  | ##8                                   |   8%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | ##########1                           |  28%
# tensorflow-base-2.17 | 156.0 MB  | ##8                                   |   8%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | ###########4                          |  31%
# arrow-cpp-19.0.0     | 12.5 MB   | ##############################4       |  82%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | ############2                         |  33%
# tensorflow-base-2.17 | 156.0 MB  | ##8                                   |   8%
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ##8                                   |   8%
# arrow-cpp-19.0.0     | 12.5 MB   | ##############################9       |  84%
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ##8                                   |   8%
# arrow-cpp-19.0.0     | 12.5 MB   | ###############################3      |  85%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | ###############6                      |  42%
# tensorflow-base-2.17 | 156.0 MB  | ##8                                   |   8%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | #################5                    |  47%
# tensorflow-base-2.17 | 156.0 MB  | ##9                                   |   8%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | ###################3                  |  52%
# tensorflow-base-2.17 | 156.0 MB  | ##9                                   |   8%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | #####################1                |  57%
# tensorflow-base-2.17 | 156.0 MB  | ##9                                   |   8%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | #######################2              |  63%
# tensorflow-base-2.17 | 156.0 MB  | ##9                                   |   8%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | #########################             |  68%
# tensorflow-base-2.17 | 156.0 MB  | ##9                                   |   8%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | ##########################8           |  73%
# tensorflow-base-2.17 | 156.0 MB  | ##9                                   |   8%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | #############################1        |  79%
# tensorflow-base-2.17 | 156.0 MB  | ###                                   |   8%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | ##############################9       |  84%
# arrow-cpp-19.0.0     | 12.5 MB   | ###################################6  |  96%
#
#
#
#
#
#
# keras-3.6.0          | 3.0 MB    | ##################################### | 100%
#
# libgrpc-1.62.2       | 8.0 MB    | #########################4            |  69%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | ################################7     |  89%
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ###                                   |   8%
# arrow-cpp-19.0.0     | 12.5 MB   | ####################################1 |  98%
#
# libgrpc-1.62.2       | 8.0 MB    | #############################6        |  80%
#
#
#
#
#
#
#
#
# pytables-3.10.2      | 1.7 MB    | ####6                                 |  13%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | ##################################2   |  92%
# tensorflow-base-2.17 | 156.0 MB  | ###                                   |   8%
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ###                                   |   8%
# arrow-cpp-19.0.0     | 12.5 MB   | ####################################9 | 100%
# arrow-cpp-19.0.0     | 12.5 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
# pytables-3.10.2      | 1.7 MB    | #########                             |  24%
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ###                                   |   8%
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ###1                                  |   8%
#
# libgrpc-1.62.2       | 8.0 MB    | ##############################8       |  83%
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ###1                                  |   9%
#
#
#
#
#
#
#
#
# pytables-3.10.2      | 1.7 MB    | #################                     |  46%
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ###1                                  |   9%
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ###2                                  |   9%
#
#
#
#
#
#
#
#
# pytables-3.10.2      | 1.7 MB    | ########################3             |  66%
#
# tensorflow-base-2.17 | 156.0 MB  | ###2                                  |   9%
#
#
#
#
#
#
#
#
# pytables-3.10.2      | 1.7 MB    | ##########################7           |  72%
#
# tensorflow-base-2.17 | 156.0 MB  | ###2                                  |   9%
#
# tensorflow-base-2.17 | 156.0 MB  | ###3                                  |   9%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# pytables-3.10.2      | 1.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ###3                                  |   9%
#
# libgrpc-1.62.2       | 8.0 MB    | #################################2    |  90%
#
#
#
#
#
#
#
#
#
#
# libabseil-20240116.2 | 1.3 MB    | 4                                     |   1%
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ###3                                  |   9%
#
#
#
#
#
#
#
#
#
#
# libabseil-20240116.2 | 1.3 MB    | ##7                                   |   7%
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ###3                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
# orc-2.0.1            | 1.1 MB    | 5                                     |   1%
#
#
#
#
#
#
#
#
#
#
# libabseil-20240116.2 | 1.3 MB    | ########2                             |  22%
#
#
#
#
#
#
#
#
#
# h5py-3.12.1          | 1.4 MB    | ########4                             |  23%
#
# tensorflow-base-2.17 | 156.0 MB  | ###3                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
# orc-2.0.1            | 1.1 MB    | ###6                                  |  10%
#
#
#
#
#
#
#
#
#
#
# libabseil-20240116.2 | 1.3 MB    | ############4                         |  34%
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ###3                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ###3                                  |   9%
#
#
#
#
#
#
#
#
#
#
# libabseil-20240116.2 | 1.3 MB    | ################5                     |  45%
#
#
#
#
#
#
#
#
#
# h5py-3.12.1          | 1.4 MB    | ################9                     |  46%
#
# tensorflow-base-2.17 | 156.0 MB  | ###3                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
# orc-2.0.1            | 1.1 MB    | ############8                         |  35%
#
#
#
#
#
#
#
#
#
#
# libabseil-20240116.2 | 1.3 MB    | ######################1               |  60%
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ###4                                  |   9%
#
# libgrpc-1.62.2       | 8.0 MB    | ##################################    |  92%
#
#
#
#
#
#
#
#
#
#
# libabseil-20240116.2 | 1.3 MB    | ##########################2           |  71%
#
#
#
#
#
#
#
#
#
# h5py-3.12.1          | 1.4 MB    | ##########################2           |  71%
#
#
#
#
#
#
#
#
#
#
#
# orc-2.0.1            | 1.1 MB    | ################4                     |  45%
#
# tensorflow-base-2.17 | 156.0 MB  | ###4                                  |   9%
#
#
#
#
#
#
#
#
#
#
# libabseil-20240116.2 | 1.3 MB    | #############################4        |  80%
#
#
#
#
#
#
#
#
#
#
# libabseil-20240116.2 | 1.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# orc-2.0.1            | 1.1 MB    | #########################2            |  68%
#
#
#
#
#
#
#
#
#
# h5py-3.12.1          | 1.4 MB    | ###############################1      |  84%
#
# tensorflow-base-2.17 | 156.0 MB  | ###4                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ###4                                  |   9%
#
# tensorflow-base-2.17 | 156.0 MB  | ###4                                  |   9%
#
# libgrpc-1.62.2       | 8.0 MB    | ###################################1  |  95%
#
#
#
#
#
#
#
#
#
#
#
# orc-2.0.1            | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# h5py-3.12.1          | 1.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ###8                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# optree-0.14.1        | 420 KB    | #4                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
# grpcio-1.62.2        | 1.1 MB    | 5                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-estimator | 714 KB    | 8                                     |   2%
#
# libgrpc-1.62.2       | 8.0 MB    | ##################################### | 100%
#
# libgrpc-1.62.2       | 8.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# optree-0.14.1        | 420 KB    | ###############5                      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
# grpcio-1.62.2        | 1.1 MB    | #####9                                |  16%
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-estimator | 714 KB    | ####1                                 |  11%
#
#
#
#
#
#
# keras-3.6.0          | 3.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-estimator | 714 KB    | #######4                              |  20%
#
#
#
#
#
#
#
#
#
#
#
#
# grpcio-1.62.2        | 1.1 MB    | ###########4                          |  31%
#
#
#
#
#
#
#
#
# pytables-3.10.2      | 1.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# grpcio-1.62.2        | 1.1 MB    | ###############2                      |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-estimator | 714 KB    | ##########7                           |  29%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# protobuf-4.25.3      | 409 KB    | #4                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
# grpcio-1.62.2        | 1.1 MB    | ###################5                  |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-estimator | 714 KB    | ###################9                  |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# protobuf-4.25.3      | 409 KB    | ###########5                          |  31%
#
#
#
#
#
#
#
#
#
#
#
#
# grpcio-1.62.2        | 1.1 MB    | #######################9              |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-estimator | 714 KB    | ########################8             |  67%
#
#
#
#
#
#
#
#
#
#
#
#
# grpcio-1.62.2        | 1.1 MB    | ###########################7          |  75%
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-estimator | 714 KB    | #############################8        |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# protobuf-4.25.3      | 409 KB    | ##################8                   |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# optree-0.14.1        | 420 KB    | #############################6        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# optree-0.14.1        | 420 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# grpcio-1.62.2        | 1.1 MB    | ###############################5      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ###9                                  |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# protobuf-4.25.3      | 409 KB    | ########################6             |  67%
#
#
#
#
#
#
#
#
#
#
#
#
# grpcio-1.62.2        | 1.1 MB    | ###################################3  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# protobuf-4.25.3      | 409 KB    | ##############################4       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ####8                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-estimator | 714 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# protobuf-4.25.3      | 409 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# grpcio-1.62.2        | 1.1 MB    | ##################################### | 100%
# tensorflow-base-2.17 | 156.0 MB  | ####8                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# snappy-1.2.1         | 46 KB     | ############8                         |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ml_dtypes-0.4.0      | 171 KB    | ###4                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
# orc-2.0.1            | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# snappy-1.2.1         | 46 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gast-0.5.3           | 21 KB     | ###########################5          |  75%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gast-0.5.3           | 21 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-2.17.0    | 33 KB     | #################9                    |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-2.17.0    | 33 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ml_dtypes-0.4.0      | 171 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# namex-0.0.7          | 16 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | #####                                 |  14%
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | #######2                              |  20%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# optree-0.14.1        | 420 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | #######4                              |  20%
#
#
#
#
#
#
#
#
#
#
# libabseil-20240116.2 | 1.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | #######6                              |  21%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ########7                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ########8                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# snappy-1.2.1         | 46 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# snappy-1.2.1         | 46 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gast-0.5.3           | 21 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gast-0.5.3           | 21 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-2.17.0    | 33 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-2.17.0    | 33 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ml_dtypes-0.4.0      | 171 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | ########9                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.17 | 156.0 MB  | #########4                            |  25%
#
#
#
#
#
#
#
#
#
#
#
#
# grpcio-1.62.2        | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# doneg transaction: -
# donection: -
# done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install R
# Out:
# /media/obarreto/MSDOSX/library-iso/anaconda-navigator/lib/python3.11/site-packages/conda/base/context.py:201: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# /media/obarreto/MSDOSX/library-iso/anaconda-navigator/lib/python3.11/site-packages/conda/base/context.py:201: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# Channels:
#  - defaults
# Platform: linux-64
# doneackage metadata (repodata.json): -
# doneronment: -
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
restart
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 restart
#
# NameError: name 'restart' is not defined
