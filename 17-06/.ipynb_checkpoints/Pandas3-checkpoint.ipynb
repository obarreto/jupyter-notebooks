# %%
import pandas as pd
import numpy as np


data = {'Estado' : ['São Paulo','São Paulo','São Paulo','Paraná','Paraná','Paraná','Paraná','Santa Catarina','Santa Catarina','Santa Catarina',
                    'Rio de Janeiro','Rio de Janeiro','Bahia','Bahia','Bahia','Bahia'],'Ano':[2000,2001,2002,2001,2002,2003,2004, 2000
                    ,2001,2002,2002,2003,2001,2002,2003,2004],'População':[1,2,3,4,1,2,3,1,2,4,5,1,2,3,2,3]}
data1 = {'Estado' : ['São Paulo','São Paulo','Paraná','Rio de Janeiro'],'Ano':[2002,2003,2004, 2000],'População':[1,2,3,4]}

df = pd.DataFrame(data)

df1 = pd.DataFrame(data1, index=['a','w','c','d'])

df
# Out:
#             Estado   Ano  População
# 0        São Paulo  2000          1
# 1        São Paulo  2001          2
# 2        São Paulo  2002          3
# 3           Paraná  2001          4
# 4           Paraná  2002          1
# 5           Paraná  2003          2
# 6           Paraná  2004          3
# 7   Santa Catarina  2000          1
# 8   Santa Catarina  2001          2
# 9   Santa Catarina  2002          4
# 10  Rio de Janeiro  2002          5
# 11  Rio de Janeiro  2003          1
# 12           Bahia  2001          2
# 13           Bahia  2002          3
# 14           Bahia  2003          2
# 15           Bahia  2004          3

# %%
df.columns
# Out:
# Index(['Estado', 'Ano', 'População'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=16, step=1)

# %%
df.head(7)
# Out:
#       Estado   Ano  População
# 0  São Paulo  2000          1
# 1  São Paulo  2001          2
# 2  São Paulo  2002          3
# 3     Paraná  2001          4
# 4     Paraná  2002          1
# 5     Paraná  2003          2
# 6     Paraná  2004          3

# %%
df.tail(4)
# Out:
#    Estado   Ano  População
# 12  Bahia  2001          2
# 13  Bahia  2002          3
# 14  Bahia  2003          2
# 15  Bahia  2004          3

# %%
df['Estado']
# Out:
# 0          São Paulo
# 1          São Paulo
# 2          São Paulo
# 3             Paraná
# 4             Paraná
# 5             Paraná
# 6             Paraná
# 7     Santa Catarina
# 8     Santa Catarina
# 9     Santa Catarina
# 10    Rio de Janeiro
# 11    Rio de Janeiro
# 12             Bahia
# 13             Bahia
# 14             Bahia
# 15             Bahia
# Name: Estado, dtype: object

# %%
df[['Estado','Ano']]
# Out:
#             Estado   Ano
# 0        São Paulo  2000
# 1        São Paulo  2001
# 2        São Paulo  2002
# 3           Paraná  2001
# 4           Paraná  2002
# 5           Paraná  2003
# 6           Paraná  2004
# 7   Santa Catarina  2000
# 8   Santa Catarina  2001
# 9   Santa Catarina  2002
# 10  Rio de Janeiro  2002
# 11  Rio de Janeiro  2003
# 12           Bahia  2001
# 13           Bahia  2002
# 14           Bahia  2003
# 15           Bahia  2004

# %%
df.Estado
# Out:
# 0          São Paulo
# 1          São Paulo
# 2          São Paulo
# 3             Paraná
# 4             Paraná
# 5             Paraná
# 6             Paraná
# 7     Santa Catarina
# 8     Santa Catarina
# 9     Santa Catarina
# 10    Rio de Janeiro
# 11    Rio de Janeiro
# 12             Bahia
# 13             Bahia
# 14             Bahia
# 15             Bahia
# Name: Estado, dtype: object

# %%
c = ['População','Estado']
print(c)
df[c]
# Out:
# ['População', 'Estado']
#     População          Estado
# 0           1       São Paulo
# 1           2       São Paulo
# 2           3       São Paulo
# 3           4          Paraná
# 4           1          Paraná
# 5           2          Paraná
# 6           3          Paraná
# 7           1  Santa Catarina
# 8           2  Santa Catarina
# 9           4  Santa Catarina
# 10          5  Rio de Janeiro
# 11          1  Rio de Janeiro
# 12          2           Bahia
# 13          3           Bahia
# 14          2           Bahia
# 15          3           Bahia

# %%
for x in c:
  print(df[x])
# Out:
# 0     1
# 1     2
# 2     3
# 3     4
# 4     1
# 5     2
# 6     3
# 7     1
# 8     2
# 9     4
# 10    5
# 11    1
# 12    2
# 13    3
# 14    2
# 15    3
# Name: População, dtype: int64
# 0          São Paulo
# 1          São Paulo
# 2          São Paulo
# 3             Paraná
# 4             Paraná
# 5             Paraná
# 6             Paraná
# 7     Santa Catarina
# 8     Santa Catarina
# 9     Santa Catarina
# 10    Rio de Janeiro
# 11    Rio de Janeiro
# 12             Bahia
# 13             Bahia
# 14             Bahia
# 15             Bahia
# Name: Estado, dtype: object

# %%
df
# Out:
#             Estado   Ano  População
# 0        São Paulo  2000          1
# 1        São Paulo  2001          2
# 2        São Paulo  2002          3
# 3           Paraná  2001          4
# 4           Paraná  2002          1
# 5           Paraná  2003          2
# 6           Paraná  2004          3
# 7   Santa Catarina  2000          1
# 8   Santa Catarina  2001          2
# 9   Santa Catarina  2002          4
# 10  Rio de Janeiro  2002          5
# 11  Rio de Janeiro  2003          1
# 12           Bahia  2001          2
# 13           Bahia  2002          3
# 14           Bahia  2003          2
# 15           Bahia  2004          3

# %%
df.loc[5:10]
# Out:
#             Estado   Ano  População
# 5           Paraná  2003          2
# 6           Paraná  2004          3
# 7   Santa Catarina  2000          1
# 8   Santa Catarina  2001          2
# 9   Santa Catarina  2002          4
# 10  Rio de Janeiro  2002          5

# %%
df['Debito'] = ''
df
# Out:
#             Estado   Ano  População Debito
# 0        São Paulo  2000          1
# 1        São Paulo  2001          2
# 2        São Paulo  2002          3
# 3           Paraná  2001          4
# 4           Paraná  2002          1
# 5           Paraná  2003          2
# 6           Paraná  2004          3
# 7   Santa Catarina  2000          1
# 8   Santa Catarina  2001          2
# 9   Santa Catarina  2002          4
# 10  Rio de Janeiro  2002          5
# 11  Rio de Janeiro  2003          1
# 12           Bahia  2001          2
# 13           Bahia  2002          3
# 14           Bahia  2003          2
# 15           Bahia  2004          3

# %%
df2 = pd.DataFrame(data, columns=['Estado','Ano','População','Debt'])
df2
# Out:
#             Estado   Ano  População Debt
# 0        São Paulo  2000          1  NaN
# 1        São Paulo  2001          2  NaN
# 2        São Paulo  2002          3  NaN
# 3           Paraná  2001          4  NaN
# 4           Paraná  2002          1  NaN
# 5           Paraná  2003          2  NaN
# 6           Paraná  2004          3  NaN
# 7   Santa Catarina  2000          1  NaN
# 8   Santa Catarina  2001          2  NaN
# 9   Santa Catarina  2002          4  NaN
# 10  Rio de Janeiro  2002          5  NaN
# 11  Rio de Janeiro  2003          1  NaN
# 12           Bahia  2001          2  NaN
# 13           Bahia  2002          3  NaN
# 14           Bahia  2003          2  NaN
# 15           Bahia  2004          3  NaN

# %%
df2['Soma']= np.arange(0,1.6,0.1)
df2
# Out:
#             Estado   Ano  População Debt  Soma
# 0        São Paulo  2000          1  NaN   0.0
# 1        São Paulo  2001          2  NaN   0.1
# 2        São Paulo  2002          3  NaN   0.2
# 3           Paraná  2001          4  NaN   0.3
# 4           Paraná  2002          1  NaN   0.4
# 5           Paraná  2003          2  NaN   0.5
# 6           Paraná  2004          3  NaN   0.6
# 7   Santa Catarina  2000          1  NaN   0.7
# 8   Santa Catarina  2001          2  NaN   0.8
# 9   Santa Catarina  2002          4  NaN   0.9
# 10  Rio de Janeiro  2002          5  NaN   1.0
# 11  Rio de Janeiro  2003          1  NaN   1.1
# 12           Bahia  2001          2  NaN   1.2
# 13           Bahia  2002          3  NaN   1.3
# 14           Bahia  2003          2  NaN   1.4
# 15           Bahia  2004          3  NaN   1.5

# %%
s1 = pd.Series([-2.4,3,2.3], index=[11,13,15])
s1
# Out:
# 11   -2.4
# 13    3.0
# 15    2.3
# dtype: float64

# %%
df2['Debt']= s1
df2
# Out:
#             Estado   Ano  População  Debt  Soma
# 0        São Paulo  2000          1   NaN   0.0
# 1        São Paulo  2001          2   NaN   0.1
# 2        São Paulo  2002          3   NaN   0.2
# 3           Paraná  2001          4   NaN   0.3
# 4           Paraná  2002          1   NaN   0.4
# 5           Paraná  2003          2   NaN   0.5
# 6           Paraná  2004          3   NaN   0.6
# 7   Santa Catarina  2000          1   NaN   0.7
# 8   Santa Catarina  2001          2   NaN   0.8
# 9   Santa Catarina  2002          4   NaN   0.9
# 10  Rio de Janeiro  2002          5   NaN   1.0
# 11  Rio de Janeiro  2003          1  -2.4   1.1
# 12           Bahia  2001          2   NaN   1.2
# 13           Bahia  2002          3   3.0   1.3
# 14           Bahia  2003          2   NaN   1.4
# 15           Bahia  2004          3   2.3   1.5

# %%
df3 = df2.copy()
df3 = df3.dropna()
df3
# Out:
#             Estado   Ano  População  Debt  Soma
# 11  Rio de Janeiro  2003          1  -2.4   1.1
# 13           Bahia  2002          3   3.0   1.3
# 15           Bahia  2004          3   2.3   1.5

# %%
df3 = df2.copy()
df3 = df3.fillna(df3['Debt'].mean())

df3
# Out:
#             Estado   Ano  População      Debt  Soma
# 0        São Paulo  2000          1  0.966667   0.0
# 1        São Paulo  2001          2  0.966667   0.1
# 2        São Paulo  2002          3  0.966667   0.2
# 3           Paraná  2001          4  0.966667   0.3
# 4           Paraná  2002          1  0.966667   0.4
# 5           Paraná  2003          2  0.966667   0.5
# 6           Paraná  2004          3  0.966667   0.6
# 7   Santa Catarina  2000          1  0.966667   0.7
# 8   Santa Catarina  2001          2  0.966667   0.8
# 9   Santa Catarina  2002          4  0.966667   0.9
# 10  Rio de Janeiro  2002          5  0.966667   1.0
# 11  Rio de Janeiro  2003          1 -2.400000   1.1
# 12           Bahia  2001          2  0.966667   1.2
# 13           Bahia  2002          3  3.000000   1.3
# 14           Bahia  2003          2  0.966667   1.4
# 15           Bahia  2004          3  2.300000   1.5

# %%
df3 = df2.copy()
df3 = df3.fillna(df3['Debt'].mean())

df3.loc[df3['Debt']>2]
# Out:
#    Estado   Ano  População  Debt  Soma
# 13  Bahia  2002          3   3.0   1.3
# 15  Bahia  2004          3   2.3   1.5

# %%
df3
# Out:
#             Estado   Ano  População      Debt  Soma
# 0        São Paulo  2000          1  0.966667   0.0
# 1        São Paulo  2001          2  0.966667   0.1
# 2        São Paulo  2002          3  0.966667   0.2
# 3           Paraná  2001          4  0.966667   0.3
# 4           Paraná  2002          1  0.966667   0.4
# 5           Paraná  2003          2  0.966667   0.5
# 6           Paraná  2004          3  0.966667   0.6
# 7   Santa Catarina  2000          1  0.966667   0.7
# 8   Santa Catarina  2001          2  0.966667   0.8
# 9   Santa Catarina  2002          4  0.966667   0.9
# 10  Rio de Janeiro  2002          5  0.966667   1.0
# 11  Rio de Janeiro  2003          1 -2.400000   1.1
# 12           Bahia  2001          2  0.966667   1.2
# 13           Bahia  2002          3  3.000000   1.3
# 14           Bahia  2003          2  0.966667   1.4
# 15           Bahia  2004          3  2.300000   1.5

# %%
nordeste = df2['Estado'] == 'Bahia'

sudeste = df2['Estado'].isin(['São Paulo','Rio de Janeiro'])

sul = df2['Estado'].isin(['Santa Catarina','Paraná'])


df2['Região'][nordeste] = 'Nordeste' 

df2['Região'][sudeste]= 'Sudeste'

df2['Região'][sul]= 'Sul'


df2
# Out:
#             Estado   Ano  População  Debt  Soma    Região
# 0        São Paulo  2000          1   NaN   0.0   Sudeste
# 1        São Paulo  2001          2   NaN   0.1   Sudeste
# 2        São Paulo  2002          3   NaN   0.2   Sudeste
# 3           Paraná  2001          4   NaN   0.3       Sul
# 4           Paraná  2002          1   NaN   0.4       Sul
# 5           Paraná  2003          2   NaN   0.5       Sul
# 6           Paraná  2004          3   NaN   0.6       Sul
# 7   Santa Catarina  2000          1   NaN   0.7       Sul
# 8   Santa Catarina  2001          2   NaN   0.8       Sul
# 9   Santa Catarina  2002          4   NaN   0.9       Sul
# 10  Rio de Janeiro  2002          5   NaN   1.0   Sudeste
# 11  Rio de Janeiro  2003          1  -2.4   1.1   Sudeste
# 12           Bahia  2001          2   NaN   1.2  Nordeste
# 13           Bahia  2002          3   3.0   1.3  Nordeste
# 14           Bahia  2003          2   NaN   1.4  Nordeste
# ...

# %%
df2['Estado'].unique()
# Out:
# array(['São Paulo', 'Paraná', 'Santa Catarina', 'Rio de Janeiro', 'Bahia'],
#       dtype=object)

# %%
df2['Debt'].fillna(0, inplace=True)

# %%
df2
# Out:
#             Estado   Ano  População  Debt  Soma    Região
# 0        São Paulo  2000          1   0.0   0.0   Sudeste
# 1        São Paulo  2001          2   0.0   0.1   Sudeste
# 2        São Paulo  2002          3   0.0   0.2   Sudeste
# 3           Paraná  2001          4   0.0   0.3       Sul
# 4           Paraná  2002          1   0.0   0.4       Sul
# 5           Paraná  2003          2   0.0   0.5       Sul
# 6           Paraná  2004          3   0.0   0.6       Sul
# 7   Santa Catarina  2000          1   0.0   0.7       Sul
# 8   Santa Catarina  2001          2   0.0   0.8       Sul
# 9   Santa Catarina  2002          4   0.0   0.9       Sul
# 10  Rio de Janeiro  2002          5   0.0   1.0   Sudeste
# 11  Rio de Janeiro  2003          1  -2.4   1.1   Sudeste
# 12           Bahia  2001          2   0.0   1.2  Nordeste
# 13           Bahia  2002          3   3.0   1.3  Nordeste
# 14           Bahia  2003          2   0.0   1.4  Nordeste
# ...

# %%
df2['Debt'].describe()
# Out:
# count    16.000000
# mean      0.181250
# std       1.140888
# min      -2.400000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       3.000000
# Name: Debt, dtype: float64

# %%
df2[['População','Debt','Soma']].describe()
# Out:
#        População       Debt       Soma
# count  16.000000  16.000000  16.000000
# mean    2.437500   0.181250   0.750000
# std     1.209339   1.140888   0.476095
# min     1.000000  -2.400000   0.000000
# 25%     1.750000   0.000000   0.375000
# 50%     2.000000   0.000000   0.750000
# 75%     3.000000   0.000000   1.125000
# max     5.000000   3.000000   1.500000

# %%
df2[['População','Debt','Soma']].describe().T
# Out:
#            count     mean       std  min    25%   50%    75%  max
# População   16.0  2.43750  1.209339  1.0  1.750  2.00  3.000  5.0
# Debt        16.0  0.18125  1.140888 -2.4  0.000  0.00  0.000  3.0
# Soma        16.0  0.75000  0.476095  0.0  0.375  0.75  1.125  1.5

# %%
df2
# Out:
#             Estado   Ano  População  Debt  Soma    Região
# 0        São Paulo  2000          1   0.0   0.0   Sudeste
# 1        São Paulo  2001          2   0.0   0.1   Sudeste
# 2        São Paulo  2002          3   0.0   0.2   Sudeste
# 3           Paraná  2001          4   0.0   0.3       Sul
# 4           Paraná  2002          1   0.0   0.4       Sul
# 5           Paraná  2003          2   0.0   0.5       Sul
# 6           Paraná  2004          3   0.0   0.6       Sul
# 7   Santa Catarina  2000          1   0.0   0.7       Sul
# 8   Santa Catarina  2001          2   0.0   0.8       Sul
# 9   Santa Catarina  2002          4   0.0   0.9       Sul
# 10  Rio de Janeiro  2002          5   0.0   1.0   Sudeste
# 11  Rio de Janeiro  2003          1  -2.4   1.1   Sudeste
# 12           Bahia  2001          2   0.0   1.2  Nordeste
# 13           Bahia  2002          3   3.0   1.3  Nordeste
# 14           Bahia  2003          2   0.0   1.4  Nordeste
# ...

# %%
df2.groupby(['Estado','Ano']).sum()
# Out:
#                      População  Debt  Soma
# Estado         Ano
# Bahia          2001          2   0.0   1.2
#                2002          3   3.0   1.3
#                2003          2   0.0   1.4
#                2004          3   2.3   1.5
# Paraná         2001          4   0.0   0.3
#                2002          1   0.0   0.4
#                2003          2   0.0   0.5
#                2004          3   0.0   0.6
# Rio de Janeiro 2002          5   0.0   1.0
#                2003          1  -2.4   1.1
# Santa Catarina 2000          1   0.0   0.7
#                2001          2   0.0   0.8
#                2002          4   0.0   0.9
# São Paulo      2000          1   0.0   0.0
#                2001          2   0.0   0.1
#                2002          3   0.0   0.2

# %%
df2.groupby(['Ano','Estado']).sum()
# Out:
#                      População  Debt  Soma
# Ano  Estado
# 2000 Santa Catarina          1   0.0   0.7
#      São Paulo               1   0.0   0.0
# 2001 Bahia                   2   0.0   1.2
#      Paraná                  4   0.0   0.3
#      Santa Catarina          2   0.0   0.8
#      São Paulo               2   0.0   0.1
# 2002 Bahia                   3   3.0   1.3
#      Paraná                  1   0.0   0.4
#      Rio de Janeiro          5   0.0   1.0
#      Santa Catarina          4   0.0   0.9
#      São Paulo               3   0.0   0.2
# 2003 Bahia                   2   0.0   1.4
#      Paraná                  2   0.0   0.5
#      Rio de Janeiro          1  -2.4   1.1
# 2004 Bahia                   3   2.3   1.5
#      Paraná                  3   0.0   0.6

# %%
df2.groupby(['Ano','Região']).sum()
# Out:
#                População  Debt  Soma
# Ano  Região
# 2000 Sudeste           1   0.0   0.0
#      Sul               1   0.0   0.7
# 2001 Nordeste          2   0.0   1.2
#      Sudeste           2   0.0   0.1
#      Sul               6   0.0   1.1
# 2002 Nordeste          3   3.0   1.3
#      Sudeste           8   0.0   1.2
#      Sul               5   0.0   1.3
# 2003 Nordeste          2   0.0   1.4
#      Sudeste           1  -2.4   1.1
#      Sul               2   0.0   0.5
# 2004 Nordeste          3   2.3   1.5
#      Sul               3   0.0   0.6

# %%
df2.groupby(['Ano']).sum()
# Out:
#       População  Debt  Soma
# Ano
# 2000          2   0.0   0.7
# 2001         10   0.0   2.4
# 2002         16   3.0   3.8
# 2003          5  -2.4   3.0
# 2004          6   2.3   2.1

# %%
df2.groupby(['Estado']).sum()
# Out:
#                  Ano  População  Debt  Soma
# Estado
# Bahia           8010         10   5.3   5.4
# Paraná          8010         10   0.0   1.8
# Rio de Janeiro  4005          6  -2.4   2.1
# Santa Catarina  6003          7   0.0   2.4
# São Paulo       6003          6   0.0   0.3

# %%
df2.groupby(['Estado'])[['População','Debt','Soma']].sum()
# Out:
#                 População  Debt  Soma
# Estado
# Bahia                  10   5.3   5.4
# Paraná                 10   0.0   1.8
# Rio de Janeiro          6  -2.4   2.1
# Santa Catarina          7   0.0   2.4
# São Paulo               6   0.0   0.3

# %%
df2G = df2.groupby(['Estado'])[['População','Soma']].sum()

# %%
import matplotlib.pyplot as plt
df2G = df2G.T
df2G.plot(kind='bar')
plt.show()

# %%
df2.groupby(['Região','Estado'])[['População','Debt','Soma']].sum()
# Out:
#                          População  Debt  Soma
# Região   Estado
# Nordeste Bahia                  10   5.3   5.4
# Sudeste  Rio de Janeiro          6  -2.4   2.1
#          São Paulo               6   0.0   0.3
# Sul      Paraná                 10   0.0   1.8
#          Santa Catarina          7   0.0   2.4

# %%
df2G = df2.groupby(['Região'])[['População','Debt','Soma']].sum()
df2G = df2G.T
df2G.plot(kind='bar')
plt.show()
