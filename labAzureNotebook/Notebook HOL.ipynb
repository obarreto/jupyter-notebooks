# %%
"""
Learn about Azure

https://github.com/Microsoft/computerscience/blob/master/Labs/AI%20and%20Machine%20Learning/Azure%20Notebooks/Azure%20Notebooks.md#Exercise1
"""

# %%
#Azure notebooks Hand on Lab

import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
import seaborn as sns; sns.set()

# %%
#Exercise 2: Upload data and create a scatter plot.
yearsBase, meanBase = np.loadtxt('5-year-mean-1951-1980.csv', delimiter=',', usecols=(0, 1), unpack=True)
years, mean = np.loadtxt('5-year-mean-1882-2014.csv', delimiter=',', usecols=(0, 1), unpack=True)

# %%
#Create a scatter plot

# %%
#Exercise 3: Perform linear regression with Numpy 
#Create a linear regression from the Data points
m,b = np.polyfit(yearsBase, meanBase, 1)

#This a simple y = mx + b line fuction
def f(x): 
    return m*x + b

#This generates the same scatter plot as before, but adds line plot using the function above
plt.scatter(yearsBase, meanBase)
plt.plot(yearsBase, f(yearsBase))
plt.title('scatter plot of mean temp difference vs year')
plt.xlabel('years', fontsize=12)
plt.ylabel('mean temp difference', fontsize=12);
plt.show()

#Prints text to the screen showing the computed values of m and b
print(' y = {0} * x + {1}'.format (m, b))
plt.show()
# Out:
#  y = 0.007279199110122221 * x + -14.309265850945222

# %%
# Exercise 4: Perform linear regression with Scikit-Learn 

# Pick the linear regression model instatiate it
model = LinearRegression (fit_intercept=True)

# Fit/Build the model
model.fit(yearsBase[:, np.newaxis], meanBase)
mean_predicted = model.predict(yearsBase[:, np.newaxis])

#Generate a plot like the one in the previous exercise 
plt.scatter(yearsBase, meanBase)
plt.plot(yearsBase, mean_predicted)
plt.title('Scatter plot of mean tem difference vs year')
plt.xlabel('years', fontsize=12)
plt.ylabel('mean temp difference', fontsize=12)
plt.show()

print(' y = {0} * x + {1}'. format (model.coef_[0], model.intercept_))
# Out:
#  y = 0.007279199110122357 * x + -14.309265850945492

# %%
# Exercise 5: Anlyze the data with Seaborn
plt.scatter(yearsBase, meanBase)
plt.title('Scatter plot of mean tem difference vs year')
plt.xlabel('years', fontsize=12)
plt.ylabel('mean temp difference', fontsize=12)

# Seaborn
sns.regplot(yearsBase, meanBase)

plt.show()
