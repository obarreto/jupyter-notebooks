# %%
import yfinance as yf
import pandas as pd
import plotly.graph_objects as go
import matplotlib.pyplot as plt
# %matplotlib inline

# Baixar dados diretamente com yfinance
acao = "IRBR3.SA"
df = yf.download(acao, start="2021-07-15", end="2023-08-03")

# Exibir os dados
print(df.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open   Volume
# Ticker        IRBR3.SA    IRBR3.SA    IRBR3.SA    IRBR3.SA IRBR3.SA
# Date
# 2021-07-15  139.144592  142.629425  138.895676  141.384842   585235
# 2021-07-16  138.895676  141.135925  138.895676  139.642426   595355
# 2021-07-19  136.904327  138.397842  136.406494  138.148926   911139
# 2021-07-20  137.651093  138.397842  135.908661  136.904327   580157
# 2021-07-21  149.350189  149.848022  138.646759  138.895676  2668347

# %%
fig = go.Figure(data=[go.Candlestick(
    x=df.index,
    open=df['Open'],
    high=df['High'],
    low=df['Low'],
    close=df['Close']
)])

fig.update_layout(title=f"Gráfico Candlestick - {acao}", xaxis_title="Data", yaxis_title="Preço")
fig.show()
