# %%
"""
Em Python os blocos condicionais devem seguir uma identação

if condição:
   comandoV1
   comandoV2
   comandoV3
else:
   comandoF1
   comandoF2
comandoSeguinte
"""

# %%
temperatura = 99
if temperatura > 100:

    print(boll)
    evaporação = "Muito rápido"
else:
    print("Água não está em ponto ebolição!")
# Out:
# Água não está em ponto ebolição!

# %%
tempoDeJogo = int( input("Quano temos já jogado ?")) 

if tempoDeJogo <= 90: 
    print("Ainda tem jogo pela frente") 
    print("Que bom, eu adoro futebol")
else:
    print("Putz, tá acabando o jogo")
    print("Apita logo juiz !")
# Out:
# Quano temos já jogado ?60
# Ainda tem jogo pela frente
# Que bom, eu adoro futebol

# %%
#Exercicios
#1. O que é impresso ao digitar: 
1 + 1 + 1 == 3
# Out:
# True

# %%
#2. Considere que a variável is_ready é dotipo booleano. Qual decalração 
#está correta e é a forma mais sucinta de testar se is_re_ready é verdaeiro ?
is_ready = True
print(is_ready == True)
# Out:
# True

# %%
type(is_ready)
# Out:
# bool

# %%
#3. A liguagem Python permite o uso de funções matemáticas. Porém, não 
#são nativas da liguagem e ficam localizadas em módulos externos.
#Para se usar a função sqrt, por exemplo, é ncessário usar o seguinte comando:

import math
math.sqrt(144)
math.pow(3,2)
# Out:
# 9.0

# %%
#4. Considere o trecho de comando abaixo. Qual o numero da linha que
#será reponsável pela saída (apresentação do resultador ao usuário) desse código ?
texto = "computação"
if len(texto) > 10:
    print("texto com mais de 10 caracteres")
else:
    print("texto com 10 ou menos caracteres")
# Out:
# texto com 10 ou menos caracteres

# %%
#5.A lesgilação de trânsito do Brasil permite que apenas pessoas
#com no mínimo 18 anos possam habilitar-se para dirigir.
#
#Cosidere que exista um variável idade e voce deverá testar se o usuário pode 
#dirigir ou não e em seguida, exibir uma mensagem correpondente à sua situação
#Todas a opções abaixo dão o resultado correto, porém qual delas utilliza melhor o recurso do if..else?


idade = int( input("Informe sua idade"))
#I
if (idade < 18):
     print ("Não pode tirar carteira de habilitação")
if (idade >= 18):
     print ("Pode tirar a carteira de habilitação")

#II
if (idade < 18):
    print ("Não pode tirar carteira de habilitação")
else:
    print("*** Pode tirar a carteira de habilitação ***")

#III
if (idade < 18):
     print ("Não pode tirar carteira de habilitação")
else:
    if (idade >=18):
        print("Pode tirar a carteira de habilitação")

#IV
if (idade < 18):
    print ("Não pode tirar carteira de habilitação")
else:
    if (idade == 18):
        print("Pode tirar a carteira de habilitação")
    else:
        if(idade > 18):
            print("Pode tirar a carteira de habilitação")
# Out:
# Informe sua idade31
# Pode tirar a carteira de habilitação
# *** Pode tirar a carteira de habilitação ***
# Pode tirar a carteira de habilitação
# Pode tirar a carteira de habilitação

# %%
#6. Após executar a atribuição x = 10, qual afirmativa é verdadeira ?
x = 10
x != 20
# Out:
# True

# %%
#7. Qual(is) dos seguintes comandos é(são) equivalente(s) a x != y?
x = 10
y = 20

x != y

not(x == y)
# Out:
# True

# %%
#8. Considere a = 0, b =2 e c =1. O que será impresso pelos comandos abaixo ?
a = 0
b = 2
c = 1
if(a > 0):
    if (b > 0):
        print ("Tudo ok para decolagem!")
    else:
        print ("Tanque principal vazio; voando com conbutível reserva!")
else:
    if (c > 0):
        print("Foguete não tem piloto, mas há outros foguetes disponíveis !")
# Out:
# Foguete não tem piloto, mas há outros foguetes disponíveis !

# %%
#Atividade para entregar !

# Exercício 1 - Par ou impar ?
# Receba um numero inteiro na entrada e impra PAR quando o numero for par ou impar quando onumero for impar

integer = int( input("Insira um numero inteiro: "))

x = integer % 2

if(x == 0):
    print("PAR !")
else:
    print("ÍMPAR")
# Out:
# Insira um numero inteiro: 18
# PAR !

# %%
# Exercício 2 - FizzBuzz parcial, parte 1

# Receba um número inteiro na entrada e imprima Fizz se o numero
# for divisível por 3. Caso contrário, imprima o mesmo número que 
# foi dado na entrada.

integer = int( input("Insira um numero inteiro: "))

x = integer % 3

if(x == 0):
    print("Fizz")
else:
    print(integer)
# Out:
# Insira um numero inteiro: 234
# Fizz

# %%
# Exercício 3 - FizzBuzz parcial, parte 1

# Receba um número inteiro na entrada e imprima Buzz se o numero
# for divisível por 5. Caso contrário, imprima o mesmo número que 
# foi dado na entrada.

integer = int( input("Insira um numero inteiro: "))

x = integer % 5

if(x == 0):
    print("Buzz")
else:
    print(integer)
# Out:
# Insira um numero inteiro: 25
# Buzz

# %%
# Exercício 4 - FizzBuzz parcial, parte 1

# Receba um número inteiro na entrada e imprima FizzBuzz se o numero
# for divisível por 3 e 5. Caso contrário, imprima o mesmo número que 
# foi dado na entrada.

integer = int( input("Insira um numero inteiro: "))

x = integer % 3
y = integer % 5

if(x == 0 and y == 0):
    print("FizzBuzz")
else:
    print(integer)
# Out:
# Insira um numero inteiro: 45
# FizzBuzz

# %%
# Exercício 5 - Verificando ordenação
# Receba 3 números inteiros na entrada e imprima crescente
# se eles forem dados em ordem crescente. Caso contrário, imprima
# não está em ordem crescente.

integer1 = int( input("Insert 1st number: "))
integer2 = int( input("Insert 2st number: "))
integer3 = int( input("Insert 3st number: "))

if(integer1 < integer2 and integer2 < integer3):
    print("Crescente")
else:
        print("Não está em ordem crescente")
# Out:
# Insert 1st number: 55
# Insert 2st number: 100
# Insert 3st number: 1001
# Crescente
